# %% [markdown]
# # PyCity Schools Analysis
#
# * As a whole, schools with higher budgets, did not yield better test results. By contrast, schools with higher spending per student actually (\$645-675) underperformed compared to schools with smaller budgets (<\$585 per student).
#
# * As a whole, smaller and medium sized schools dramatically out-performed large sized schools on passing math performances (89-91% passing vs 67%).
#
# * As a whole, charter schools out-performed the public district schools across all metrics. However, more analysis will be required to glean if the effect is due to school practices or the fact that charter schools tend to serve smaller student populations per school.
# ---

# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# File to Load (Remember to Change These)
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas Data Frames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset
school_data_merge = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])
school_data_merge.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %% [markdown]
# ## District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the overall passing rate (overall average score), i.e. (avg. math score + avg. reading score)/2
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
school_data_merge.columns
# Out:
# Index(['Student ID', 'student_name', 'gender', 'grade', 'school_name',
#        'reading_score', 'math_score', 'School ID', 'type', 'size', 'budget'],
#       dtype='object')

# %%
total_schools=len(school_data_merge["school_name"].value_counts())

total_students=school_data_merge["Student ID"].count()

total_budget=school_data_merge["budget"].sum()

ave_math=school_data_merge["math_score"].mean()

ave_reading=school_data_merge["reading_score"].mean()

overall_pass_score=(ave_math + ave_reading)/2

math_pass_num=school_data_merge.loc[school_data_merge["math_score"] >= 70, ["math_score"]]
math_pass_percentage =math_pass_num['math_score'].count()/ total_students


reading_pass_num=school_data_merge.loc[school_data_merge["reading_score"] >= 70, ["reading_score"]]
reading_pass_percentage=reading_pass_num['reading_score'].count()/total_students

# %%
district_summary_df = pd.DataFrame({
    "Total Schools": [total_schools],
    "Total Students": [total_students],
    "Total Budget":[total_budget],
    "Average Math Score": [ave_math],
    "Average Reading Score": [ave_reading],
    "Overall Pass Score": [overall_pass_score],
    "% Passing Math": [math_pass_percentage],
    "% Passing Reading": [reading_pass_percentage]
})


district_summary_df.style.format({
    "Total Budget": "${:,.2f}", 
    "Average Reading Score": "{:.1f}", 
    "Average Math Score": "{:.1f}", 
    "% Passing Math": "{:.1%}", 
    "% Passing Reading": "{:.1%}", 
    "Overall Passing Rate": "{:.1%}"
})
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_db6d1c3a_a885_11e8_be86_acde48001122" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Total Schools</th>
#         <th class="col_heading level0 col1" >Total Students</th>
#         <th class="col_heading level0 col2" >Total Budget</th>
#         <th class="col_heading level0 col3" >Average Math Score</th>
#         <th class="col_heading level0 col4" >Average Reading Score</th>
#         <th class="col_heading level0 col5" >Overall Pass Score</th>
#         <th class="col_heading level0 col6" >% Passing Math</th>
#         <th class="col_heading level0 col7" >% Passing Reading</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_db6d1c3a_a885_11e8_be86_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_db6d1c3a_a885_11e8_be86_acde48001122row0_col0" class="data row0 col0" >15</td>
#         <td id="T_db6d1c3a_a885_11e8_be86_acde48001122row0_col1" class="data row0 col1" >39170</td>
#         <td id="T_db6d1c3a_a885_11e8_be86_acde48001122row0_col2" class="data row0 col2" >$82,932,329,558.00</td>
#         <td id="T_db6d1c3a_a885_11e8_be86_acde48001122row0_col3" class="data row0 col3" >79.0</td>
#         <td id="T_db6d1c3a_a885_11e8_be86_acde48001122row0_col4" class="data row0 col4" >81.9</td>
#         <td id="T_db6d1c3a_a885_11e8_be86_acde48001122row0_col5" class="data row0 col5" >80.4316</td>
#         <td id="T_db6d1c3a_a885_11e8_be86_acde48001122row0_col6" class="data row0 col6" >75.0%</td>
#         <td id="T_db6d1c3a_a885_11e8_be86_acde48001122row0_col7" class="data row0 col7" >85.8%</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# ## School Summary

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)
#
# * Create a dataframe to hold the above results

# %%
school_type = school_data.set_index("school_name")["type"]

# %%
total_student = school_data_merge["school_name"].value_counts()

# %%
school_budget=school_data.groupby(["school_name"]).sum()["budget"]

# %%
per_student_budget= school_budget / school_student

# %%
school_ave_math=school_name["math_score"].mean()

school_ave_reading=school_name["reading_score"].mean()

# %%
mathpass_percent= school_data_merge[school_data_merge["math_score"]>70].groupby(["school_name"])
mathpass_percent = mathpass_percent["math_score"].count()/school_student

readpass_percent= school_data_merge[school_data_merge["reading_score"]>70].groupby(["school_name"])
readpass_percent = readpass_percent["reading_score"].count()/school_student

overall_pass=(mathpass_percent+ readpass_percent)/2

# %%
school_summary = pd.DataFrame({

    "School Type": school_type,
    "Total Students": school_student,
    "Total Budget":school_budget,
    "Per Student Budget": per_student_budget,
    "Average Math Score": school_ave_math,
    "Average Reading Score": school_ave_reading,
    "% Passing Math": mathpass_percent,
    "% Passing Reading": readpass_percent,
    "Overall Passing Rate": overall_pass
})


school_summary.style.format({'Total Students': '{:,}', 
                          "Total School Budget": "${:,}", 
                          "Per Student Budget": "${:.0f}",
                          'Average Math Score': "{:.1f}", 
                          'Average Reading Score': "{:.1f}", 
                          "% Passing Math": "{:.1%}", 
                          "% Passing Reading": "{:.1%}", 
                          "Overall Passing Rate": "{:.1%}"})
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_9c3ed3a4_a888_11e8_b1de_acde48001122" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >School Type</th>
#         <th class="col_heading level0 col1" >Total Students</th>
#         <th class="col_heading level0 col2" >Total Budget</th>
#         <th class="col_heading level0 col3" >Per Student Budget</th>
#         <th class="col_heading level0 col4" >Average Math Score</th>
#         <th class="col_heading level0 col5" >Average Reading Score</th>
#         <th class="col_heading level0 col6" >% Passing Math</th>
#         <th class="col_heading level0 col7" >% Passing Reading</th>
#         <th class="col_heading level0 col8" >Overall Passing Rate</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_9c3ed3a4_a888_11e8_b1de_acde48001122level0_row0" class="row_heading level0 row0" >Bailey High School</th>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row0_col0" class="data row0 col0" >District</td>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row0_col1" class="data row0 col1" >4,976</td>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row0_col2" class="data row0 col2" >3124928</td>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row0_col3" class="data row0 col3" >$628</td>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row0_col4" class="data row0 col4" >77.0</td>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row0_col5" class="data row0 col5" >81.0</td>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row0_col6" class="data row0 col6" >64.6%</td>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row0_col7" class="data row0 col7" >79.3%</td>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row0_col8" class="data row0 col8" >72.0%</td>
#     </tr>    <tr>
#         <th id="T_9c3ed3a4_a888_11e8_b1de_acde48001122level0_row1" class="row_heading level0 row1" >Cabrera High School</th>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row1_col0" class="data row1 col0" >Charter</td>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row1_col1" class="data row1 col1" >1,858</td>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row1_col2" class="data row1 col2" >1081356</td>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row1_col3" class="data row1 col3" >$582</td>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row1_col4" class="data row1 col4" >83.1</td>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row1_col5" class="data row1 col5" >84.0</td>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row1_col6" class="data row1 col6" >89.6%</td>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row1_col7" class="data row1 col7" >93.9%</td>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row1_col8" class="data row1 col8" >91.7%</td>
#     </tr>    <tr>
#         <th id="T_9c3ed3a4_a888_11e8_b1de_acde48001122level0_row2" class="row_heading level0 row2" >Figueroa High School</th>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row2_col0" class="data row2 col0" >District</td>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row2_col1" class="data row2 col1" >2,949</td>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row2_col2" class="data row2 col2" >1884411</td>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row2_col3" class="data row2 col3" >$639</td>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row2_col4" class="data row2 col4" >76.7</td>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row2_col5" class="data row2 col5" >81.2</td>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row2_col6" class="data row2 col6" >63.8%</td>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row2_col7" class="data row2 col7" >78.4%</td>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row2_col8" class="data row2 col8" >71.1%</td>
#     </tr>    <tr>
#         <th id="T_9c3ed3a4_a888_11e8_b1de_acde48001122level0_row3" class="row_heading level0 row3" >Ford High School</th>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row3_col0" class="data row3 col0" >District</td>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row3_col1" class="data row3 col1" >2,739</td>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row3_col2" class="data row3 col2" >1763916</td>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row3_col3" class="data row3 col3" >$644</td>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row3_col4" class="data row3 col4" >77.1</td>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row3_col5" class="data row3 col5" >80.7</td>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row3_col6" class="data row3 col6" >65.8%</td>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row3_col7" class="data row3 col7" >77.5%</td>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row3_col8" class="data row3 col8" >71.6%</td>
#     </tr>    <tr>
#         <th id="T_9c3ed3a4_a888_11e8_b1de_acde48001122level0_row4" class="row_heading level0 row4" >Griffin High School</th>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row4_col0" class="data row4 col0" >Charter</td>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row4_col1" class="data row4 col1" >1,468</td>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row4_col2" class="data row4 col2" >917500</td>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row4_col3" class="data row4 col3" >$625</td>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row4_col4" class="data row4 col4" >83.4</td>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row4_col5" class="data row4 col5" >83.8</td>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row4_col6" class="data row4 col6" >89.7%</td>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row4_col7" class="data row4 col7" >93.4%</td>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row4_col8" class="data row4 col8" >91.6%</td>
#     </tr>    <tr>
#         <th id="T_9c3ed3a4_a888_11e8_b1de_acde48001122level0_row5" class="row_heading level0 row5" >Hernandez High School</th>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row5_col0" class="data row5 col0" >District</td>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row5_col1" class="data row5 col1" >4,635</td>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row5_col2" class="data row5 col2" >3022020</td>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row5_col3" class="data row5 col3" >$652</td>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row5_col4" class="data row5 col4" >77.3</td>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row5_col5" class="data row5 col5" >80.9</td>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row5_col6" class="data row5 col6" >64.7%</td>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row5_col7" class="data row5 col7" >78.2%</td>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row5_col8" class="data row5 col8" >71.5%</td>
#     </tr>    <tr>
#         <th id="T_9c3ed3a4_a888_11e8_b1de_acde48001122level0_row6" class="row_heading level0 row6" >Holden High School</th>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row6_col0" class="data row6 col0" >Charter</td>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row6_col1" class="data row6 col1" >427</td>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row6_col2" class="data row6 col2" >248087</td>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row6_col3" class="data row6 col3" >$581</td>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row6_col4" class="data row6 col4" >83.8</td>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row6_col5" class="data row6 col5" >83.8</td>
#         <td id="T_9c3ed3a4_a888_11e8_b1de_acde48001122row6_col6" class="data row6 col6" >90.6%</td>
#         <td id="T_9c3ed3a4_a888_11e8_b1d

# %% [markdown]
# ## Top Performing Schools (By Passing Rate)

# %% [markdown]
# * Sort and display the top five schools in overall passing rate

# %%
top_performing_schools=school_summary.sort_values("Overall Passing Rate", ascending=False)
top_performing_schools.head(5)
# Out:
#                     School Type  Total Students  Total Budget  \
# Wilson High School      Charter            2283       1319574
# Pena High School        Charter             962        585858
# Wright High School      Charter            1800       1049400
# Cabrera High School     Charter            1858       1081356
# Holden High School      Charter             427        248087
#
#                      Per Student Budget  Average Math Score  \
# Wilson High School                578.0           83.274201
# Pena High School                  609.0           83.839917
# Wright High School                583.0           83.682222
# Cabrera High School               582.0           83.061895
# Holden High School                581.0           83.803279
#
#                      Average Reading Score  % Passing Math  % Passing Reading  \
# Wilson High School               83.989488        0.909330           0.932545
# Pena High School                 84.044699        0.916840           0.922037
# Wright High School               83.955000        0.902778           0.934444
# Cabrera High School              83.975780        0.895587           0.938644
# Holden High School               83.814988        0.906323           0.927400
#
#                      Overall Passing Rate
# Wilson High School               0.920937
# Pena High School                 0.919439
# Wright High School               0.918611
# Cabrera High School              0.917115
# Holden High School               0.916862

# %% [markdown]
# ## Bottom Performing Schools (By Passing Rate)

# %% [markdown]
# * Sort and display the five worst-performing schools

# %%
bottom_performing_schools=school_summary.sort_values("Overall Passing Rate", ascending=True)
bottom_performing_schools.head(5)
# Out:
#                       School Type  Total Students  Total Budget  \
# Rodriguez High School    District            3999       2547363
# Huang High School        District            2917       1910635
# Johnson High School      District            4761       3094650
# Figueroa High School     District            2949       1884411
# Hernandez High School    District            4635       3022020
#
#                        Per Student Budget  Average Math Score  \
# Rodriguez High School               637.0           76.842711
# Huang High School                   655.0           76.629414
# Johnson High School                 650.0           77.072464
# Figueroa High School                639.0           76.711767
# Hernandez High School               652.0           77.289752
#
#                        Average Reading Score  % Passing Math  \
# Rodriguez High School              80.744686        0.640660
# Huang High School                  81.182722        0.633185
# Johnson High School                80.966394        0.638521
# Figueroa High School               81.158020        0.637504
# Hernandez High School              80.934412        0.647465
#
#                        % Passing Reading  Overall Passing Rate
# Rodriguez High School           0.777444              0.709052
# Huang High School               0.788138              0.710662
# Johnson High School             0.782819              0.710670
# Figueroa High School            0.784334              0.710919
# Hernandez High School           0.781877              0.714671

# %% [markdown]
# ## Math Scores by Grade

# %% [markdown]
# * Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
#   * Create a pandas series for each grade. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %%
nineth_grade = school_data_merge[(school_data_merge["grade"] == "9th")]
tenth_grade = school_data_merge[(school_data_merge["grade"] == "10th")]
eleventh_grade = school_data_merge[(school_data_merge["grade"] == "11th")]
twelfth_grade = school_data_merge[(school_data_merge["grade"] == "12th")]

nineth_math = nineth_grade.groupby(["school_name"]).mean()["math_score"]
tenth_math = tenth_grade.groupby(["school_name"]).mean()["math_score"]
eleventh_math = eleventh_grade.groupby(["school_name"]).mean()["math_score"]
twelfth_math = twelfth_grade.groupby(["school_name"]).mean()["math_score"]

math_scores_by_grade = pd.DataFrame({"9th Grade": nineth_math, 
                                     "10th Grade": tenth_math,
                                     "11th Grade": eleventh_math,
                                     "12th Grade": twelfth_math})

math_scores_by_grade = math_scores_by_grade[["9th Grade", "10th Grade", "11th Grade", "12th Grade"]]

math_scores_by_grade
# Out:
#                        9th Grade  10th Grade  11th Grade  12th Grade
# school_name
# Bailey High School     77.083676   76.996772   77.515588   76.492218
# Cabrera High School    83.094697   83.154506   82.765560   83.277487
# Figueroa High School   76.403037   76.539974   76.884344   77.151369
# Ford High School       77.361345   77.672316   76.918058   76.179963
# Griffin High School    82.044010   84.229064   83.842105   83.356164
# Hernandez High School  77.438495   77.337408   77.136029   77.186567
# Holden High School     83.787402   83.429825   85.000000   82.855422
# Huang High School      77.027251   75.908735   76.446602   77.225641
# Johnson High School    77.187857   76.691117   77.491653   76.863248
# Pena High School       83.625455   83.372000   84.328125   84.121547
# Rodriguez High School  76.859966   76.612500   76.395626   77.690748
# Shelton High School    83.420755   82.917411   83.383495   83.778976
# Thomas High School     83.590022   83.087886   83.498795   83.497041
# Wilson High School     83.085578   83.724422   83.195326   83.035794
# Wright High School     83.264706   84.010288   83.836782   83.644986

# %% [markdown]
# ## Reading Score by Grade

# %% [markdown]
# * Perform the same operations as above for reading scores

# %%
nineth_grade = school_data_merge[(school_data_merge["grade"] == "9th")]
tenth_grade = school_data_merge[(school_data_merge["grade"] == "10th")]
eleventh_grade = school_data_merge[(school_data_merge["grade"] == "11th")]
twelfth_grade = school_data_merge[(school_data_merge["grade"] == "12th")]

nineth_reading = nineth_grade.groupby(["school_name"]).mean()["reading_score"]
tenth_reading = tenth_grade.groupby(["school_name"]).mean()["reading_score"]
eleventh_reading = eleventh_grade.groupby(["school_name"]).mean()["reading_score"]
twelfth_reading = twelfth_grade.groupby(["school_name"]).mean()["reading_score"]

reading_scores_by_grade = pd.DataFrame({"9th Grade": nineth_reading, 
                                     "10th Grade": tenth_reading,
                                     "11th Grade": eleventh_reading,
                                     "12th Grade": twelfth_reading})

reading_scores_by_grade = reading_scores_by_grade[["9th Grade", "10th Grade", "11th Grade", "12th Grade"]]

reading_scores_by_grade
# Out:
#                        9th Grade  10th Grade  11th Grade  12th Grade
# school_name
# Bailey High School     81.303155   80.907183   80.945643   80.912451
# Cabrera High School    83.676136   84.253219   83.788382   84.287958
# Figueroa High School   81.198598   81.408912   80.640339   81.384863
# Ford High School       80.632653   81.262712   80.403642   80.662338
# Griffin High School    83.369193   83.706897   84.288089   84.013699
# Hernandez High School  80.866860   80.660147   81.396140   80.857143
# Holden High School     83.677165   83.324561   83.815534   84.698795
# Huang High School      81.290284   81.512386   81.417476   80.305983
# Johnson High School    81.260714   80.773431   80.616027   81.227564
# Pena High School       83.807273   83.612000   84.335938   84.591160
# Rodriguez High School  80.993127   80.629808   80.864811   80.376426
# Shelton High School    84.122642   83.441964   84.373786   82.781671
# Thomas High School     83.728850   84.254157   83.585542   83.831361
# Wilson High School     83.939778   84.021452   83.764608   84.317673
# Wright High School     83.833333   83.812757   84.156322   84.073171

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %%
# Sample bins. Feel free to create your own bins.
spending_bins = [0, 585, 615, 645, 675]
group_names = ["<$585", "$585-615", "$615-645", "$645-675"]
school_summary["Per Student Budget"] = pd.cut(per_student_budget, spending_bins, labels=group_names)

# %%
spending_ave_math = school_summary.groupby(["Per Student Budget"]).mean()["Average Math Score"]
spending_ave_read = school_summary.groupby(["Per Student Budget"]).mean()["Average Reading Score"]
spending_pass_math = school_summary.groupby(["Per Student Budget"]).mean()["% Passing Math"]
spending_pass_read = school_summary.groupby(["Per Student Budget"]).mean()["% Passing Reading"]
spending_overall= (spending_pass_math + spending_pass_read)/2

# %%
school_spending_summary = pd.DataFrame({"Average Math Score": spending_ave_math,
                                                  "Average Reading Score": spending_ave_read,
                                                  "% Passing Math": spending_pass_math,
                                                  "% Passing Reading": spending_pass_read, 
                                                  "Overall Passing Rate": spending_overall})

school_spending_summary
# Out:
#                     Average Math Score  Average Reading Score  % Passing Math  \
# Per Student Budget
# <$585                        83.455399              83.933814        0.903504
# $585-615                     83.599686              83.885211        0.907880
# $615-645                     79.079225              81.891436        0.730214
# $645-675                     76.997210              81.027843        0.639724
#
#                     % Passing Reading  Overall Passing Rate
# Per Student Budget
# <$585                        0.933258              0.918381
# $585-615                     0.924108              0.915994
# $615-645                     0.832143              0.781179
# $645-675                     0.784278              0.712001

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %%
# Sample bins. Feel free to create your own bins.
size_bins = [0, 1000, 2000, 5000]
group_names = ["Small (<1000)", "Medium (1000-2000)", "Large (2000-5000)"]
school_summary["Total Students"] = pd.cut(school_student, size_bins, labels=group_names)

# %%
size_ave_math = school_summary.groupby(["Total Students"]).mean()["Average Math Score"]
size_ave_read = school_summary.groupby(["Total Students"]).mean()["Average Reading Score"]
size_pass_math = school_summary.groupby(["Total Students"]).mean()["% Passing Math"]
size_pass_read = school_summary.groupby(["Total Students"]).mean()["% Passing Reading"]
size_overall= (size_pass_math + size_pass_read)/2

# %%
school_size_summary = pd.DataFrame({"Average Math Score": size_ave_math,
                                                  "Average Reading Score": size_ave_read,
                                                  "% Passing Math": size_pass_math,
                                                  "% Passing Reading": size_pass_read, 
                                                  "Overall Passing Rate": size_overall})

school_size_summary
# Out:
#                     Average Math Score  Average Reading Score  % Passing Math  \
# Total Students
# Small (<1000)                83.821598              83.929843        0.911582
# Medium (1000-2000)           83.374684              83.864438        0.899313
# Large (2000-5000)            77.746417              81.344493        0.676313
#
#                     % Passing Reading  Overall Passing Rate
# Total Students
# Small (<1000)                0.924719              0.918150
# Medium (1000-2000)           0.932448              0.915881
# Large (2000-5000)            0.801908              0.739111

# %% [markdown]
# ## Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type.

# %%
score_by_type = school_data_merged_.groupby("type")

# %%
type_ave_math = school_summary.groupby(["School Type"]).mean()["Average Math Score"]
type_ave_read = school_summary.groupby(["School Type"]).mean()["Average Reading Score"]
type_pass_math = school_summary.groupby(["School Type"]).mean()["% Passing Math"]
type_pass_read = school_summary.groupby(["School Type"]).mean()["% Passing Reading"]
type_overall= (type_pass_math + type_pass_read)/2

# %%
school_type_summary = pd.DataFrame({"Average Math Score": type_ave_math,
                                                  "Average Reading Score": type_ave_read,
                                                  "% Passing Math": type_pass_math,
                                                  "% Passing Reading": type_pass_read, 
                                                  "Overall Passing Rate": type_overall})

school_type_summary
# Out:
#              Average Math Score  Average Reading Score  % Passing Math  \
# School Type
# Charter               83.473852              83.896421        0.903632
# District              76.956733              80.966636        0.643025
#
#              % Passing Reading  Overall Passing Rate
# School Type
# Charter               0.930528              0.917080
# District              0.783246              0.713135
